# %% [markdown]
# ## Todo Items
#
# - [ ] change color scheme. Could look nicer.
#
# ### Done
# - [x] Fix Plotting
# - [x] get supervised MAML to work

# %%
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

from ge_maml import *

# %% [markdown]
# ## SGD Only version of MAML
#
# Key parameters include:
#
# - Set # of gradient descent to 500
# - Set `n_task` to 1,
# - Set `epoch_n` to 1

# %%
# %matplotlib notebook
logging = dict(logger=defaultdict(list), fig=plt.figure(figsize=(9, 3)))
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
from ge_maml import *

model = Model(input_n=1, output_n=1, optimizer='SGD')
_t = Problem()
maml_supervised(model, lambda: _t, n_epochs=1, task_batch_n=1, k_shot=100, n_gradient_steps=2000, 
                final_figure=None, **logging)

# %% [markdown]
# ## MAML with 10 gradient steps

# %%
# %matplotlib notebook
logging = dict(logger=defaultdict(list), fig=plt.figure(figsize=(9, 3)))
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
from ge_maml import *

model = Model(input_n=1, output_n=1, optimizer='SGD')
M.start(silent=False)
maml_supervised(model, Problem, n_epochs=500, task_batch_n=10, k_shot=100, n_gradient_steps=10, 
                final_figure=None, **logging)
M.split()

# %% [markdown]
# ## MAML with 1 gradient step

# %%
# %matplotlib notebook
logging = dict(logger=defaultdict(list), fig=plt.figure(figsize=(9, 3)))
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
from ge_maml import *

model = Model(input_n=1, output_n=1, optimizer='SGD', meta_optimizer='Adam')
M.start(silent=False)
maml_supervised(model, Problem, n_epochs=100, task_batch_n=10, k_shot=10, n_gradient_steps=1, 
                final_figure=None, **logging)
M.split()
# Out:
# Lap Time: 29.3702s

# %% [markdown]
# ## MAML with 3 gradient steps

# %%
# %matplotlib notebook
logging = dict(logger=defaultdict(list), fig=plt.figure(figsize=(9, 3)))
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
from ge_maml import *

model = Model(input_n=1, output_n=1, optimizer='SGD')
M.start(silent=False)
maml_supervised(model, Problem, n_epochs=100, task_batch_n=10, k_shot=10, n_gradient_steps=3, 
                final_figure=None, **logging)
M.split()
# Out:
# Timer Started
# Lap Time: 26.4089s

# %% [markdown]
# ## MAML with 5 gradient steps

# %%
# %matplotlib notebook
logging = dict(logger=defaultdict(list), fig=plt.figure(figsize=(9, 3)))
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
from ge_maml import *

model = Model(input_n=1, output_n=1, optimizer='SGD')
M.start(silent=False)
maml_supervised(model, Problem, n_epochs=100, task_batch_n=10, k_shot=10, n_gradient_steps=5, 
                final_figure=None, **logging)
M.split()
# Out:
# Timer Started
# Lap Time: 63.5790s

# %% [markdown]
# ## MAML with 10 gradient steps

# %%
# %matplotlib notebook
logging = dict(logger=defaultdict(list), fig=plt.figure(figsize=(9, 3)))
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
from ge_maml import *

model = Model(input_n=1, output_n=1, optimizer='SGD')
M.start(silent=False)
maml_supervised(model, Problem, n_epochs=100, task_batch_n=10, k_shot=10, n_gradient_steps=10, 
                final_figure=None, **logging)
M.split()
# Out:
# Timer Started
# Lap Time: 42.3438s
